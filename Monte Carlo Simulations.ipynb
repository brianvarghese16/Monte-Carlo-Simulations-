# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
from matplotlib.animation import FuncAnimation
from numba import jit
from time import time
from numpy.random import random
from scipy.fft import fft2, fft, fftfreq
import os

class Molecular_Dynamics:
    def __init__(self, N, L, dt, t_max, x, v, m, delta=1):
        self.L = L
        self.t_max = t_max
        self.dt = dt
        self.m = m
        self.delta = delta
        self.x = x
        self.v = v
        self.x_data = [x]
        self.v_data = [v]
        self.t = [0]
        self.pair_idx = tuple((i, i+1) for i in range(N-1))   # pair index 
        self.single_idx = (0, N-1)
        self.number_of_events = 0
        
        
    def simulation(self): 
        while self.t[-1] < t_max:
            t_event, event_idx = self.compute_next_event()
            for i in range(int(self.t[-1]/self.dt)+1, int((self.t[-1]+t_event)/dt)+1):
                self.x = np.copy(self.x + self.v * self.dt)
                self.x_data.append(self.x)
                self.v_data.append(self.v)
                self.t.append(self.t[-1] + self.dt)
                if self.t[-1] >= self.t_max: break
            self.update_v(event_idx)
            self.number_of_events += 1
            
    def get_data(self, p):
        x_data = np.array(self.x_data)[:-1]  
        v_data = np.array(self.v_data)[:-1]  
        E_data = 0.5 * self.m * v_data**2
        t = np.array(self.t)[:-1]
        if p: print("number of collisions", self.number_of_events)
        return x_data, v_data, E_data, t
        
    def pair_time(self, xi, xj, vi, vj):
        dv = vi - vj
        if dv < 0: return np.inf
        return (xj - xi - self.delta)/dv
    
    def pair_collision(self, vi, vj, mi, mj):
        vi_f = vi*(mi-mj)/(mi+mj) + vj*2*mj/(mi+mj)
        vj_f = vi*2*mi/(mi+mj) - vj*(mi-mj)/(mi+mj)
        return vi_f, vj_f
    
    def wall_time(self, x0, xN, v0, vN):
        t0 = (x0 - self.delta/2)/abs(v0) if v0 < 0 else np.inf
        tn = (L - xN - self.delta/2)/vN if vN > 0 else np.inf
        return [t0, tn]
    
    def wall_collision(self, vi):
        return -vi
    
    def compute_next_event(self):
        x, v = self.x, self.v
        pair_times = [self.pair_time(x[i], x[j], v[i], v[j]) for i, j in self.pair_idx]
        wall_times = self.wall_time(x[0], x[-1], v[0], v[-1])
        times = np.array(wall_times + pair_times)
        arg = np.argmin(times)
        t_event = times[arg]
        event_idx = self.single_idx[arg] if arg < 2 else self.pair_idx[arg-2]
        return t_event, event_idx
    
    def update_v(self, event_idx):
        v = self.v.copy()
        if type(event_idx) == tuple:
            i, j = event_idx # i and the i+1 element pair(i,j)
            v[i], v[j] = self.pair_collision(v[i], v[j], m[i], m[j])
        else:
            i = event_idx
            v[i] = self.wall_collision(v[i])
        self.v = v
        
class Monte_Carlo:
    def __init__(self, L, delta = 1, T=1):
        self.L = L # length of simulation box
        self.delta = delta # size of the particles
        self.T = T # temperature 
        
    def sample_configuration(self):
        x,m = self.sample_positions()
        N = len(x)
        v = self.sample_velocities(N, m)
        print('number of particles', N)
        return x, v, m
   
    def sample_velocities(self, N, m):
        k_b = 1.38064
        sigma = np.sqrt((k_b * self.T)/m)
        v = np.random.normal(loc = 0, scale = sigma, size=N)
        return v
    
    def sample_positions(self):
        x_positions = []
        m = np.array([])
        next_position = 0.5 + np.random.poisson(2)
        i = 0
        m1 = 1
        m2 = 5
        while next_position < self.L - 0.5:
            if i%2 == 0:
                m = np.append(m,m1)
            else:
                m = np.append(m,m2)
            if next_position < self.L - 0.5:
                x_positions.append(next_position)
                next_position = x_positions[-1] + 1 + np.random.poisson(1)
            i = i+1
        return x_positions, m
    
def observables(nbins, x_data, v_data, E_data, m, N):
    x_grid = np.linspace(0, L, nbins)
    dx = x_grid[1]
    
    enumerate(x_grid)
    
    q0 = np.zeros((len(t),len(x_grid)))
    q1 = np.zeros((len(t),len(x_grid)))
    q2 = np.zeros((len(t),len(x_grid)))
    
    j0 = np.zeros((len(t),len(x_grid)))
    j1 = np.zeros((len(t),len(x_grid)))
    j2 = np.zeros((len(t),len(x_grid)))
    
    for ((x_, v_), (E_, m_)) in zip(zip(x_data.T, v_data.T), zip(E_data.T, m)):
        for i, a in enumerate(x_grid):
            idx = np.logical_and(a < x_, x_ < a + dx)
            q0[:,i] += idx.astype(int)
            q1[:,i] += v_*m_*idx.astype(int)
            q2[:,i] += E_*idx.astype(int)
            j0[:,i] += v_*idx.astype(int)
            j1[:,i] += v_*m_*v_*idx.astype(int)
            j2[:,i] += E_*v_*idx.astype(int)
    
            
    q0 = q0 / N
    q1 = q1 / N
    q2 = q2 / N
    
    j0 = j0 / N
    j1 = j1 / N
    j2 = j2 / N
    
    return x_grid, q0, q1, q2, j0, j1, j2

L = 500
t_max = 8
dt = 0.001

MC = Monte_Carlo(L, T = 293.15)

n_MC = 1000

for i in range(n_MC):
    x, v, m = MC.sample_configuration()

    N = len(x)

    MD = Molecular_Dynamics(N, L, dt, t_max, x, v, m)
    MD.simulation()

    x_data, v_data, E_data, t = MD.get_data(p = True)

    nbins = 50

    x_grid, q0, q1, q2, j0, j1, j2 = observables(nbins, x_data, v_data, E_data, m, N)

    mid = q0.shape[1]//2 #Half of the box (position we want to correlate)#
    
    maxtime = 8000
 
    if i == 0:
        term11 = q0[0:maxtime, :] * q0[0,mid]
        term21 = q0[0:maxtime,:]
        term31 = q0[0,mid]
        
        term12 = q1[0:maxtime, :] * q1[0,mid]
        term22 = q1[0:maxtime,:]
        term32 = q1[0,mid]
        
        
        term13 = q2[0:maxtime, :] * q2[0,mid]
        term23 = q2[0:maxtime,:]
        term33 = q2[0,mid]
        
        
        term14 = j0[0:maxtime, :] * j0[0,mid]
        term24 = j0[0:maxtime,:]
        term34 = j0[0,mid]
        
        
        term15 = j1[0:maxtime, :] * j1[0,mid]
        term25 = j1[0:maxtime,:]
        term35 = j1[0,mid]
        
        
        term16 = j2[0:maxtime, :] * j2[0,mid]
        term26 = j2[0:maxtime,:]
        term36 = j2[0,mid]
        
        print(i)

    else:
        term11 += q0[0:maxtime, :] * q0[0,mid]
        term21 += q0[0:maxtime,:]
        term31 += q0[0,mid]
        
        term12 += q1[0:maxtime, :] * q1[0,mid]
        term22 += q1[0:maxtime,:]
        term32 += q1[0,mid]
        
        term13 += q2[0:maxtime, :] * q2[0,mid]
        term23 += q2[0:maxtime,:]
        term33 += q2[0,mid]
        
        term14 += j0[0:maxtime, :] * j0[0,mid]
        term24 += j0[0:maxtime,:]
        term34 += j0[0,mid]
       
        term15 += j1[0:maxtime, :] * j1[0,mid]
        term25 += j1[0:maxtime,:]
        term35 += j1[0,mid]
       
        term16 += j2[0:maxtime, :] * j2[0,mid]
        term26 += j2[0:maxtime,:]
        term36 += j2[0,mid]
        
       
        print(i)

C0 = (term11 / n_MC) - ((term31 / n_MC)*(term21 / n_MC))
C1 = (term12 / n_MC) - ((term32 / n_MC)*(term22 / n_MC))
C2 = (term13 / n_MC) - ((term33 / n_MC)*(term23 / n_MC))
C3 = (term14 / n_MC) - ((term34 / n_MC)*(term24 / n_MC))
C4 = (term15 / n_MC) - ((term35 / n_MC)*(term25 / n_MC))
C5 = (term16 / n_MC) - ((term36 / n_MC)*(term26 / n_MC))

maxtime = 8000

T, X = np.meshgrid(t[:maxtime], x_grid)

pcm1 = plt.pcolormesh(X, T, C0.T)
plt.title('Density-Density')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

pcm2 = plt.pcolormesh(X, T, C1.T)
plt.title('Momentum-Momentum')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

pcm3 = plt.pcolormesh(X, T, C2.T)
plt.title('Energy-Energy')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

pcm4 = plt.pcolormesh(X, T, C3.T)
plt.title('Density-Density')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

pcm5 = plt.pcolormesh(X, T, C4.T)
plt.title('Momentum-Momentum')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

pcm6 = plt.pcolormesh(X, T, C5.T)
plt.title('Energy-Eenrgy')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

T, X = np.meshgrid(t[:maxtime], x_grid)

C0FT1 = np.fft.fft(C0, axis = 1)
C0IFT1 = np.fft.ifft(C0FT1, axis = 0)
pcm7 = plt.pcolormesh(X, T,np.abs(C0IFT1).T, vmin = 0, vmax = 20)
plt.title('Density-Density')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C0FT2 = np.fft.fft(C0, axis = 0)
C0IFT2 = np.fft.ifft(C0FT2, axis = 1)
pcm8 = plt.pcolormesh(X, T,np.abs(C0IFT2).T, vmin = 0, vmax = 20)
plt.title('Density-Density')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C1FT1 = np.fft.fft(C1, axis = 1)
C1IFT1 = np.fft.ifft(C1FT1, axis = 0)
pcm9 = plt.pcolormesh(X, T,np.abs(C1IFT1).T, vmin = 0, vmax = 20)
plt.title('Momentum-Momentum')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C1FT2 = np.fft.fft(C1, axis = 0)
C1IFT2 = np.fft.ifft(C1FT2, axis = 1)
pcm10 = plt.pcolormesh(X, T,np.abs(C1IFT2).T, vmin = 0, vmax = 20)
plt.title('Momentum-Momentum')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C2FT1 = np.fft.fft(C2, axis = 1)
C2IFT1 = np.fft.ifft(C2FT1, axis = 0)
pcm11 = plt.pcolormesh(X, T,np.abs(C2IFT1).T, vmin = 0, vmax = 20)
plt.title('Energy-Energy')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C2FT2 = np.fft.fft(C2, axis = 0)
C2IFT2 = np.fft.ifft(C2FT2, axis = 1)
pcm12 = plt.pcolormesh(X, T,np.abs(C2IFT2).T, vmin = 0, vmax = 20)
plt.title('Energy-Energy')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C3FT1 = np.fft.fft(C3, axis = 1)
C3IFT1 = np.fft.ifft(C3FT1, axis = 0)
pcm13 = plt.pcolormesh(X, T,np.abs(C3IFT1).T, vmin = 0, vmax = 20)
plt.title('Density-Density')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C3FT2 = np.fft.fft(C3, axis = 0)
C3IFT2 = np.fft.ifft(C3FT2, axis = 1)
pcm14 = plt.pcolormesh(X, T,np.abs(C3IFT2).T, vmin = 0, vmax = 20)
plt.title('Density-Density')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C4FT1 = np.fft.fft(C4, axis = 1)
C4IFT1 = np.fft.ifft(C4FT1, axis = 0)
pcm15 = plt.pcolormesh(X, T,np.abs(C4IFT1).T, vmin = 0, vmax = 20)
plt.title('Momentum-Momentum')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C4FT2 = np.fft.fft(C4, axis = 0)
C4IFT2 = np.fft.ifft(C4FT2, axis = 1)
pcm16 = plt.pcolormesh(X, T,np.abs(C4IFT2).T, vmin = 0, vmax = 20)
plt.title('Momentum-Momentum')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C5FT1 = np.fft.fft(C5, axis = 1)
C5IFT1 = np.fft.ifft(C5FT1, axis = 0)
pcm17 = plt.pcolormesh(X, T,np.abs(C5IFT1).T, vmin = 0, vmax = 20)
plt.title('Energy-Energy')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C5FT2 = np.fft.fft(C5, axis = 0)
C5IFT2 = np.fft.ifft(C5FT2, axis = 1)
pcm18 = plt.pcolormesh(X, T,np.abs(C5IFT2).T, vmin = 0, vmax = 20)
plt.title('Energy-Energy')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()
# Out:
# number of particles 255
# number of collisions 17595
# 0
# number of particles 241
# number of collisions 16889
# 1
# number of particles 263
# number of collisions 20518
# 2
# number of particles 252
# number of collisions 17926
# 3
# number of particles 239
# number of collisions 14971
# 4
# number of particles 255
# number of collisions 18877
# 5
# number of particles 251
# number of collisions 17006
# 6
# number of particles 244
# number of collisions 16361
# 7
# number of particles 241
# number of collisions 15674
# 8
# number of particles 243
# number of collisions 14234
# 9
# number of particles 255
# number of collisions 18793
# 10
# number of particles 241
# number of collisions 13987
# 11
# number of particles 251
# number of collisions 18439
# 12
# number of particles 247
# number of collisions 15073
# 13
# number of particles 262
# number of collisions 20432
# 14
# number of particles 250
# number of collisions 16821
# 15
# number of particles 266
# number of collisions 22935
# 16
# number of particles 246
# number of collisions 16398
# 17
# number of particles 232
# number of collisions 14114
# 18
# number of particles 257
# number of collisions 18534
# 19
# number of particles 266
# number of collisions 20893
# 20
# number of particles 257
# number of collisions 19357
# 21
# number of particles 247
# number of collisions 15172
# 22
# number of particles 239
# number of collisions 14304
# 23
# number of particles 249
# number of collisions 18421
# 24
# number of particles 241
# number of collisions 16682
# 25
# number of particles 270
# number of collisions 22773
# 26
# number of particles 252
# number of collisions 17337
# 27
# number of particles 239
# number of collisions 15883
# 28
# number of particles 253
# number of collisions 17806
# 29
# number of particles 258
# number of collisions 18537
# 30
# number of particles 249
# number of collisions 16624
# 31
# number of particles 243
# number of collisions 15921
# 32
# number of particles 245
# number of collisions 16689
# 33
# number of particles 241
# number of collisions 15670
# 34
# number of particles 253
# number of collisions 19146
# 35
# number of particles 237
# number of collisions 15205
# 36
# number of particles 252
# number of collisions 18508
# 37
# number of particles 261
# number of collisions 20547
# 38
# number of particles 265
# number of collisions 22209
# 39
# number of particles 237
# number of collisions 14458
# 40
# number of particles 242
# number of collisions 16637
# 41
# number of particles 259
# number of collisions 20265
# 42
# number of particles 244
# number of collisions 16212
# 43
# number of particles 245
# number of collisions 16506
# 44
# number of particles 260
# number of collisions 19920
# 45
# number of particles 260
# number of collisions 20266
# 46
# number of particles 246
# number of collisions 17432
# 47
# number of particles 239
# number of collisions 15651
# 48
# number of particles 242
# number of collisions 16629
# 49
# number of particles 258
# number of collisions 18698
# 50
# number of particles 232
# number of collisions 14439
# 51
# number of particles 261
# number of collisions 18521
# 52
# number of particles 232
# number of collisions 14415
# 53
# number of particles 261
# number of collisions 21146
# 54
# number of particles 253
# number of collisions 17871
# 55
# number of particles 245
# number of collisions 16840
# 56
# number of particles 262
# number of collisions 21075
# 57
# number of particles 236
# number of collisions 16877
# 58
# number of particles 246
# number of collisions 18210
# 59
# number of particles 248
# number of collisions 16729
# 60
# number of particles 248
# number of collisions 18878
# 61
# number of particles 239
# number of collisions 15023
# 62
# number of particles 246
# number of collisions 16953
# 63
# number of particles 246
# number of collisions 16220
# 64
# number of particles 247
# number of collisions 16729
# 65
# number of particles 260
# number of collisions 19632
# 66
# number of particles 254
# number of collisions 18394
# 67
# number of particles 254
# number of collisions 18967
# 68
# number of particles 236
# number of collisions 14950
# 69
# number of particles 248
# number of collisions 16934
# 70
# number of particles 266
# number of collisions 21429
# 71
# number of particles 247
# number of collisions 17415
# 72
# number of particles 233
# number of collisions 14341
# 73
# number of particles 240
# number of collisions 16212
# 74
# number of particles 247
# number of collisions 18531
# 75
# number of particles 238
# number of collisions 15301
# 76
# number of particles 239
# number of collisions 15614
# 77
# number of particles 249
# number of collisions 17312
# 78
# number of particles 249
# number of collisions 17093
# 79
# number of particles 250
# number of collisions 18629
# 80
# number of particles 249
# number of collisions 18658
# 81
# number of particles 247
# number of collisions 16068
# 82
# number of particles 242
# number of collisions 16082
# 83
# number of particles 253
# number of collisions 18701
# 84
# number of particles 256
# number of collisions 18395
# 85
# number of particles 252
# number of collisions 17467
# 86
# number of particles 258
# number of collisions 18140
# 87
# number of particles 249
# number of collisions 17168
# 88
# number of particles 239
# number of collisions 15481
# 89
# number of particles 236
# number of collisions 15857
# 90
# number of particles 242
# number of collisions 15316
# 91
# number of particles 267
# number of collisions 21385
# 92
# number of particles 241
# number of collisions 15095
# 93
# number of particles 263
# number of collisions 20857
# 94
# number of particles 241
# number of collisions 15194
# 95
# number of particles 266
# number of collisions 20070
# 96
# number of particles 259
# number of collisions 21833
# 97
# number of particles 258
# number of collisions 19368
# 98
# number of particles 261
# number of collisions 20608
# 99
# number of particles 247
# number of collisions 17354
# 100
# number of particles 263
# number of collisions 19618
# 101
# number of particles 241
# number of collisions 15775
# 102
# number of particles 248
# number of collisions 17285
# 103
# number of particles 250
# number of collisions 18815
# 104
# number of particles 236
# number of collisions 12794
# 105
# number of particles 250
# number of collisions 17628
# 106
# number of particles 252
# number of collisions 18205
# 107
# number of particles 254
# number of collisions 18434
# 108
# number of particles 239
# number of collisions 16031
# 109
# number of particles 241
# number of collisions 16236
# 110
# number of particles 258
# number of collisions 19311
# 111
# number of particles 253
# number of collisions 18735
# 112
# number of particles 259
# number of collisions 18233
# 113
# number of particles 246
# number of collisions 17520
# 114
# number of particles 249
# number of collisions 18605
# 115
# number of particles 239
# number of collisions 15726
# 116
# number of particles 252
# number of collisions 17541
# 117
# number of particles 250
# number of collisions 17910
# 118
# number of particles 236
# number of collisions 14515
# 119
# number of particles 250
# number of collisions 17192
# 120
# number of particles 255
# number of collisions 18993
# 121
# number of particles 254
# number of collisions 19520
# 122
# number of particles 248
# number of collisions 17411
# 123
# number of particles 245
# number of collisions 16100
# 124
# number of particles 241
# number of collisions 15554
# 125
# number of particles 250
# number of collisions 16827
# 126
# number of particles 246
# number of collisions 17491
# 127
# number of particles 246
# number of collisions 19291
# 128
# number of particles 249
# number of collisions 16505
# 129
# number of particles 254
# number of collisions 17641
# 130
# number of particles 246
# number of collisions 17677
# 131
# number of particles 243
# number of collisions 15797
# 132
# number of particles 250
# number of collisions 17318
# 133
# number of particles 248
# number of collisions 16432
# 134
# number of particles 264
# number of collisions 21014
# 135
# number of particles 257
# number of collisions 20387
# 136
# number of particles 248
# number of collisions 16870
# 137
# number of particles 243
# number of collisions 16785
# 138
# number of particles 250
# number of collisions 17151
# 139
# number of particles 245
# number of collisions 17722
# 140
# number of particles 248
# number of collisions 16444
# 141
# number of particles 228
# number of collisions 13086
# 142
# number of particles 248
# number of collisions 17713
# 143
# number of particles 257
# number of collisions 18810
# 144
# number of particles 241
# number of collisions 16151
# 145
# number of particles 248
# number of collisions 16650
# 146
# number of particles 242
# number of collisions 16783
# 147
# number of particles 255
# number of collisions 19304
# 148
# number of particles 251
# number of collisions 17457
# 149
# number of particles 245
# number of collisions 17787
# 150
# number of particles 237
# number of collisions 15212
# 151
# number of particles 245
# number of collisions 16778
# 152
# number of particles 245
# number of collisions 17648
# 153
# number of particles 259
# number of collisions 19500
# 154
# number of particles 253
# number of collisions 18706
# 155
# number of particles 245
# number of collisions 17577
# 156
# number of particles 247
# number of collisions 17346
# 157
# number of particles 250
# number of collisions 16955
# 158
# number of particles 248
# number of collisions 16830
# 159
# number of particles 252
# number of collisions 18995
# 160
# number of particles 242
# number of collisions 16953
# 161
# number of particles 251
# number of collisions 16960
# 162
# number of particles 252
# number of collisions 18575
# 163
# number of particles 246
# number of collisions 17008
# 164
# number of particles 246
# number of collisions 16064
# 165
# number of particles 243
# number of collisions 15984
# 166
# number of particles 251
# number of collisions 17791
# 167
# number of particles 252
# number of collisions 17452
# 168
# number of particles 247
# number of collisions 17602
# 169
# number of particles 248
# number of collisions 17301
# 170
# number of particles 236
# number of collisions 15288
# 171
# number of particles 248
# number of collisions 16966
# 172
# number of particles 253
# number of collisions 18034
# 173
# number of particles 236
# number of collisions 14376
# 174
# number of particles 247
# number of collisions 16078
# 175
# number of particles 248
# number of collisions 17081
# 176
# number of particles 241
# number of collisions 15191
# 177
# number of particles 242
# number of collisions 14880
# 178
# number of particles 260
# number of collisions 20302
# 179
# number of particles 238
# number of collisions 15857
# 180
# number of particles 249
# number of collisions 17751
# 181
# number of particles 241
# number of collisions 15805
# 182
# number of particles 253
# number of collisions 17967
# 183
# number of particles 247
# number of collisions 16780
# 184
# number of particles 253
# number of collisions 19535
# 185
# number of particles 252
# number of collisions 19443
# 186
# number of particles 264
# number of collisions 21397
# 187
# number of particles 241
# number of collisions 15924
# 188
# number of particles 244
# number of collisions 16162
# 189
# number of particles 240
# number of collisions 14803
# 190
# number of particles 246
# number of collisions 17215
# 191
# number of particles 259
# number of collisions 19870
# 192
# number of particles 247
# number of collisions 16459
# 193
# number of particles 255
# number of collisions 18453
# 194
# number of particles 246
# number of collisions 16310
# 195
# number of particles 236
# number of collisions 14776
# 196
# number of particles 250
# number of collisions 18030
# 197
# number of particles 265
# number of collisions 22062
# 198
# number of particles 243
# number of collisions 16823
# 199
# number of particles 244
# number of collisions 15939
# 200
# number of particles 244
# number of collisions 17149
# 201
# number of particles 255
# number of collisions 18181
# 202
# number of particles 245
# number of collisions 17603
# 203
# number of particles 249
# number of collisions 17022
# 204
# number of particles 257
# number of collisions 17838
# 205
# number of particles 246
# number of collisions 17593
# 206
# number of particles 248
# number of collisions 16946
# 207
# number of particles 253
# number of collisions 19536
# 208
# number of particles 234
# number of collisions 15618
# 209
# number of particles 252
# number of collisions 18997
# 210
# number of particles 252
# number of collisions 17140
# 211
# number of particles 251
# number of collisions 18085
# 212
# number of particles 254
# number of collisions 19578
# 213
# number of particles 253
# number of collisions 17673
# 214
# number of particles 256
# number of collisions 18766
# 215
# number of particles 260
# number of collisions 21225
# 216
# number of particles 258
# number of collisions 18505
# 217
# number of particles 240
# number of collisions 13921
# 218
# number of particles 243
# number of collisions 17618
# 219
# number of particles 248
# number of collisions 18042
# 220
# number of particles 235
# number of collisions 13800
# 221
# number of particles 246
# number of collisions 16914
# 222
# number of particles 253
# number of collisions 18608
# 223
# number of particles 242
# number of collisions 16109
# 224
# number of particles 259
# number of collisions 20343
# 225
# number of particles 251
# number of collisions 16733
# 226
# number of particles 237
# number of collisions 14765
# 227
# number of particles 237
# number of collisions 15090
# 228
# number of particles 254
# number of collisions 16244
# 229
# number of particles 254
# number of collisions 19854
# 230
# number of particles 258
# number of collisions 20361
# 231
# number of particles 257
# number of collisions 19094
# 232
# number of particles 247
# number of collisions 17711
# 233
# number of particles 244
# number of collisions 16408
# 234
# number of particles 236
# number of collisions 14837
# 235
# number of particles 252
# number of collisions 19126
# 236
# number of particles 254
# number of collisions 18299
# 237
# number of particles 248
# number of collisions 17457
# 238
# number of particles 263
# number of collisions 22121
# 239
# number of particles 251
# number of collisions 19561
# 240
# number of particles 257
# number of collisions 20252
# 241
# number of particles 257
# number of collisions 18268
# 242
# number of particles 252
# number of collisions 18558
# 243
# number of particles 251
# number of collisions 18787
# 244
# number of particles 247
# number of collisions 17880
# 245
# number of particles 246
# number of collisions 17018
# 246
# number of particles 252
# number of collisions 17971
# 247
# number of particles 256
# number of collisions 20207
# 248
# number of particles 253
# number of collisions 19264
# 249
# number of particles 256
# number of collisions 19628
# 250
# number of particles 242
# number of collisions 17050
# 251
# number of particles 243
# number of collisions 15751
# 252
# number of particles 253
# number of collisions 19262
# 253
# number of particles 249
# number of collisions 19420
# 254
# number of particles 256
# number of collisions 18626
# 255
# number of particles 256
# number of collisions 17443
# 256
# number of particles 250
# number of collisions 18523
# 257
# number of particles 264
# number of collisions 21088
# 258
# number of particles 255
# number of collisions 18100
# 259
# number of particles 248
# number of collisions 18324
# 260
# number of particles 224
# number of collisions 14144
# 261
# number of particles 241
# number of collisions 17498
# 262
# number of particles 245
# number of collisions 16893
# 263
# number of particles 255
# number of collisions 16965
# 264
# number of particles 259
# number of collisions 19636
# 265
# number of particles 270
# number of collisions 22039
# 266
# number of particles 253
# number of collisions 17879
# 267
# number of particles 242
# number of collisions 15718
# 268
# number of particles 234
# number of collisions 13456
# 269
# number of particles 240
# number of collisions 15662
# 270
# number of particles 248
# number of collisions 18604
# 271
# number of particles 240
# number of collisions 14601
# 272
# number of particles 236
# number of collisions 14690
# 273
# number of particles 245
# number of collisions 16679
# 274
# number of particles 244
# number of collisions 15542
# 275
# number of particles 245
# number of collisions 16513
# 276
# number of particles 257
# number of collisions 19614
# 277
# number of particles 254
# number of collisions 17878
# 278
# number of particles 272
# number of collisions 21726
# 279
# number of particles 236
# number of collisions 15424
# 280
# number of particles 246
# number of collisions 17813
# 281
# number of particles 241
# number of collisions 17024
# 282
# number of particles 256
# number of collisions 18032
# 283
# number of particles 250
# number of collisions 18773
# 284
# number of particles 251
# number of collisions 17819
# 285
# number of particles 252
# number of collisions 17648
# 286
# number of particles 254
# number of collisions 18831
# 287
# number of particles 256
# number of collisions 18884
# 288
# number of particles 254
# number of collisions 19609
# 289
# number of particles 247
# number of collisions 17188
# 290
# number of particles 251
# number of collisions 18313
# 291
# number of particles 240
# number of collisions 14042
# 292
# number of particles 248
# number of collisions 15153
# 293
# number of particles 241
# number of collisions 14764
# 294
# number of particles 253
# number of collisions 19533
# 295
# number of particles 252
# number of collisions 18975
# 296
# number of particles 251
# number of collisions 17976
# 297
# number of particles 262
# number of collisions 21763
# 298
# number of particles 240
# number of collisions 16598
# 299
# number of particles 248
# number of collisions 17635
# 300
# number of particles 264
# number of collisions 21150
# 301
# number of particles 258
# number of collisions 19575
# 302
# number of particles 243
# number of collisions 17484
# 303
# number of particles 255
# number of collisions 18326
# 304
# number of particles 254
# number of collisions 19436
# 305
# number of particles 240
# number of collisions 16082
# 306
# number of particles 250
# number of collisions 18188
# 307
# number of particles 247
# number of collisions 17417
# 308
# number of particles 248
# number of collisions 16384
# 309
# number of particles 238
# number of collisions 14129
# 310
# number of particles 258
# number of collisions 19088
# 311
# number of particles 255
# number of collisions 18959
# 312
# number of particles 235
# number of collisions 14917
# 313
# number of particles 237
# number of collisions 16086
# 314
# number of particles 253
# number of collisions 19579
# 315
# number of particles 250
# number of collisions 17867
# 316
# number of particles 264
# number of collisions 19619
# 317
# number of particles 248
# number of collisions 17170
# 318
# number of particles 242
# number of collisions 15688
# 319
# number of particles 244
# number of collisions 15715
# 320
# number of particles 246
# number of collisions 16959
# 321
# number of particles 245
# number of collisions 16363
# 322
# number of particles 253
# number of collisions 18188
# 323
# number of particles 252
# number of collisions 19155
# 324
# number of particles 249
# number of collisions 18072
# 325
# number of particles 256
# number of collisions 17943
# 326
# number of particles 230
# number of collisions 15180
# 327
# number of particles 255
# number of collisions 18155
# 328
# number of particles 248
# number of collisions 17461
# 329
# number of particles 247
# number of collisions 15876
# 330
# number of particles 222
# number of collisions 11967
# 331
# number of particles 242
# number of collisions 16065
# 332
# number of particles 261
# number of collisions 20536
# 333
# number of particles 255
# number of collisions 18032
# 334
# number of particles 248
# number of collisions 17321
# 335
# number of particles 254
# number of collisions 20023
# 336
# number of particles 230
# number of collisions 13707
# 337
# number of particles 253
# number of collisions 17715
# 338
# number of particles 251
# number of collisions 18245
# 339
# number of particles 252
# number of collisions 16379
# 340
# number of particles 249
# number of collisions 17766
# 341
# number of particles 246
# number of collisions 16285
# 342
# number of particles 232
# number of collisions 14195
# 343
# number of particles 239
# number of collisions 14816
# 344
# number of particles 246
# number of collisions 16361
# 345
# number of particles 249
# number of collisions 17626
# 346
# number of particles 258
# number of collisions 21458
# 347
# number of particles 232
# number of collisions 15103
# 348
# number of particles 247
# number of collisions 18142
# 349
# number of particles 254
# number of collisions 17512
# 350
# number of particles 238
# number of collisions 14303
# 351
# number of particles 255
# number of collisions 20203
# 352
# number of particles 258
# number of collisions 18582
# 353
# number of particles 251
# number of collisions 17385
# 354
# number of particles 243
# number of collisions 16624
# 355
# number of particles 250
# number of collisions 16777
# 356
# number of particles 251
# number of collisions 19091
# 357
# number of particles 250
# number of collisions 16682
# 358
# number of particles 245
# number of collisions 18575
# 359
# number of particles 262
# number of collisions 20224
# 360
# number of particles 243
# number of collisions 16953
# 361
# number of particles 252
# number of collisions 16764
# 362
# number of particles 262
# number of collisions 19146
# 363
# number of particles 254
# number of collisions 19621
# 364
# number of particles 255
# number of collisions 20182
# 365
# number of particles 251
# number of collisions 16589
# 366
# number of particles 248
# number of collisions 16901
# 367
# number of particles 256
# number of collisions 19101
# 368
# number of particles 247
# number of collisions 16504
# 369
# number of particles 246
# number of collisions 17016
# 370
# number of particles 251
# number of collisions 17267
# 371
# number of particles 251
# number of collisions 18718
# 372
# number of particles 251
# number of collisions 17399
# 373
# number of particles 240
# number of collisions 15831
# 374
# number of particles 237
# number of collisions 14563
# 375
# number of particles 241
# number of collisions 15794
# 376
# number of particles 264
# number of collisions 19942
# 377
# number of particles 247
# number of collisions 16987
# 378
# number of particles 246
# number of collisions 17578
# 379
# number of particles 253
# number of collisions 18676
# 380
# number of particles 261
# number of collisions 19532
# 381
# number of particles 253
# number of collisions 18286
# 382
# number of particles 250
# number of collisions 17988
# 383
# number of particles 248
# number of collisions 16676
# 384
# number of particles 249
# number of collisions 18349
# 385
# number of particles 251
# number of collisions 19089
# 386
# number of particles 259
# number of collisions 19627
# 387
# number of particles 267
# number of collisions 21557
# 388
# number of particles 252
# number of collisions 20106
# 389
# number of particles 252
# number of collisions 18837
# 390
# number of particles 253
# number of collisions 18377
# 391
# number of particles 242
# number of collisions 16758
# 392
# number of particles 244
# number of collisions 15831
# 393
# number of particles 244
# number of collisions 17553
# 394
# number of particles 241
# number of collisions 15371
# 395
# number of particles 255
# number of collisions 19336
# 396
# number of particles 249
# number of collisions 18320
# 397
# number of particles 246
# number of collisions 17224
# 398
# number of particles 248
# number of collisions 17028
# 399
# number of particles 243
# number of collisions 16253
# 400
# number of particles 251
# number of collisions 18655
# 401
# number of particles 247
# number of collisions 16734
# 402
# number of particles 260
# number of collisions 18791
# 403
# number of particles 247
# number of collisions 16650
# 404
# number of particles 249
# number of collisions 17732
# 405
# number of particles 253
# number of collisions 18416
# 406
# number of particles 251
# number of collisions 18202
# 407
# number of particles 253
# number of collisions 18432
# 408
# number of particles 244
# number of collisions 17494
# 409
# number of particles 238
# number of collisions 15691
# 410
# number of particles 268
# number of collisions 22043
# 411
# number of particles 251
# number of collisions 17487
# 412
# number of particles 244
# number of collisions 16992
# 413
# number of particles 249
# number of collisions 17048
# 414
# number of particles 248
# number of collisions 16723
# 415
# number of particles 242
# number of collisions 16147
# 416
# number of particles 252
# number of collisions 18320
# 417
# number of particles 244
# number of collisions 16558
# 418
# number of particles 243
# number of collisions 15432
# 419
# number of particles 250
# number of collisions 16322
# 420
# number of particles 261
# number of collisions 20694
# 421
# number of particles 256
# number of collisions 19130
# 422
# number of particles 258
# number of collisions 19437
# 423
# number of particles 236
# number of collisions 15312
# 424
# number of particles 247
# number of collisions 16680
# 425
# number of particles 245
# number of collisions 17081
# 426
# number of particles 256
# number of collisions 18758
# 427
# number of particles 237
# number of collisions 15933
# 428
# number of particles 246
# number of collisions 17439
# 429
# number of particles 243
# number of collisions 16991
# 430
# number of particles 247
# number of collisions 16913
# 431
# number of particles 257
# number of collisions 18349
# 432
# number of particles 250
# number of collisions 16371
# 433
# number of particles 245
# number of collisions 17723
# 434
# number of particles 241
# number of collisions 15852
# 435
# number of particles 253
# number of collisions 18351
# 436
# number of particles 252
# number of collisions 20366
# 437
# number of particles 262
# number of collisions 20062
# 438
# number of particles 248
# number of collisions 16890
# 439
# number of particles 243
# number of collisions 14677
# 440
# number of particles 265
# number of collisions 21711
# 441
# number of particles 238
# number of collisions 15192
# 442
# number of particles 254
# number of collisions 16592
# 443
# number of particles 247
# number of collisions 17665
# 444
# number of particles 258
# number of collisions 18576
# 445
# number of particles 251
# number of collisions 18877
# 446
# number of particles 249
# number of collisions 19541
# 447
# number of particles 242
# number of collisions 15690
# 448
# number of particles 236
# number of collisions 14688
# 449
# number of particles 237
# number of collisions 15163
# 450
# number of particles 248
# number of collisions 16719
# 451
# number of particles 248
# number of collisions 17453
# 452
# number of particles 242
# number of collisions 16268
# 453
# number of particles 249
# number of collisions 17436
# 454
# number of particles 247
# number of collisions 18108
# 455
# number of particles 268
# number of collisions 23203
# 456
# number of particles 245
# number of collisions 17418
# 457
# number of particles 243
# number of collisions 16070
# 458
# number of particles 257
# number of collisions 19442
# 459
# number of particles 242
# number of collisions 16130
# 460
# number of particles 253
# number of collisions 17459
# 461
# number of particles 241
# number of collisions 16153
# 462
# number of particles 264
# number of collisions 21815
# 463
# number of particles 238
# number of collisions 14932
# 464
# number of particles 250
# number of collisions 17680
# 465
# number of particles 233
# number of collisions 13552
# 466
# number of particles 243
# number of collisions 16074
# 467
# number of particles 248
# number of collisions 17533
# 468
# number of particles 240
# number of collisions 15467
# 469
# number of particles 258
# number of collisions 18745
# 470
# number of particles 254
# number of collisions 19937
# 471
# number of particles 239
# number of collisions 16322
# 472
# number of particles 238
# number of collisions 14635
# 473
# number of particles 258
# number of collisions 19129
# 474
# number of particles 241
# number of collisions 16913
# 475
# number of particles 241
# number of collisions 15713
# 476
# number of particles 241
# number of collisions 15177
# 477
# number of particles 253
# number of collisions 18307
# 478
# number of particles 243
# number of collisions 16925
# 479
# number of particles 247
# number of collisions 17058
# 480
# number of particles 248
# number of collisions 18044
# 481
# number of particles 243
# number of collisions 17175
# 482
# number of particles 250
# number of collisions 18016
# 483
# number of particles 246
# number of collisions 16261
# 484
# number of particles 256
# number of collisions 19108
# 485
# number of particles 258
# number of collisions 20196
# 486
# number of particles 242
# number of collisions 15236
# 487
# number of particles 263
# number of collisions 21503
# 488
# number of particles 252
# number of collisions 18668
# 489
# number of particles 236
# number of collisions 14832
# 490
# number of particles 232
# number of collisions 14381
# 491
# number of particles 256
# number of collisions 19772
# 492
# number of particles 247
# number of collisions 17309
# 493
# number of particles 252
# number of collisions 18069
# 494
# number of particles 236
# number of collisions 15537
# 495
# number of particles 238
# number of collisions 14341
# 496
# number of particles 256
# number of collisions 19840
# 497
# number of particles 261
# number of collisions 20829
# 498
# number of particles 234
# number of collisions 14653
# 499
# number of particles 256
# number of collisions 19521
# 500
# number of particles 248
# number of collisions 16942
# 501
# number of particles 244
# number of collisions 16291
# 502
# number of particles 252
# number of collisions 18201
# 503
# number of particles 239
# number of collisions 15058
# 504
# number of particles 258
# number of collisions 21673
# 505
# number of particles 234
# number of collisions 15601
# 506
# number of particles 256
# number of collisions 19121
# 507
# number of particles 243
# number of collisions 17075
# 508
# number of particles 243
# number of collisions 15780
# 509
# number of particles 239
# number of collisions 13813
# 510
# number of particles 241
# number of collisions 17929
# 511
# number of particles 240
# number of collisions 15854
# 512
# number of particles 246
# number of collisions 16834
# 513
# number of particles 267
# number of collisions 21271
# 514
# number of particles 240
# number of collisions 15990
# 515
# number of particles 253
# number of collisions 17772
# 516
# number of particles 234
# number of collisions 14326
# 517
# number of particles 246
# number of collisions 16691
# 518
# number of particles 252
# number of collisions 18079
# 519
# number of particles 245
# number of collisions 18113
# 520
# number of particles 253
# number of collisions 17005
# 521
# number of particles 252
# number of collisions 16510
# 522
# number of particles 247
# number of collisions 17224
# 523
# number of particles 249
# number of collisions 18818
# 524
# number of particles 260
# number of collisions 20100
# 525
# number of particles 244
# number of collisions 16799
# 526
# number of particles 244
# number of collisions 16932
# 527
# number of particles 255
# number of collisions 17345
# 528
# number of particles 248
# number of collisions 17910
# 529
# number of particles 256
# number of collisions 18828
# 530
# number of particles 256
# number of collisions 17720
# 531
# number of particles 242
# number of collisions 14585
# 532
# number of particles 253
# number of collisions 17750
# 533
# number of particles 257
# number of collisions 18826
# 534
# number of particles 243
# number of collisions 15161
# 535
# number of particles 244
# number of collisions 15821
# 536
# number of particles 241
# number of collisions 15503
# 537
# number of particles 263
# number of collisions 22070
# 538
# number of particles 262
# number of collisions 19589
# 539
# number of particles 258
# number of collisions 19846
# 540
# number of particles 250
# number of collisions 17115
# 541
# number of particles 265
# number of collisions 20890
# 542
# number of particles 251
# number of collisions 16997
# 543
# number of particles 247
# number of collisions 16849
# 544
# number of particles 240
# number of collisions 15830
# 545
# number of particles 246
# number of collisions 15925
# 546
# number of particles 265
# number of collisions 19677
# 547
# number of particles 253
# number of collisions 18304
# 548
# number of particles 250
# number of collisions 18420
# 549
# number of particles 258
# number of collisions 18959
# 550
# number of particles 260
# number of collisions 21285
# 551
# number of particles 259
# number of collisions 19394
# 552
# number of particles 252
# number of collisions 18260
# 553
# number of particles 260
# number of collisions 19274
# 554
# number of particles 258
# number of collisions 20873
# 555
# number of particles 250
# number of collisions 17931
# 556
# number of particles 247
# number of collisions 16556
# 557
# number of particles 241
# number of collisions 15246
# 558
# number of particles 240
# number of collisions 15769
# 559
# number of particles 254
# number of collisions 19560
# 560
# number of particles 251
# number of collisions 18518
# 561
# number of particles 266
# number of collisions 22191
# 562
# number of particles 241
# number of collisions 16812
# 563
# number of particles 245
# number of collisions 16345
# 564
# number of particles 247
# number of collisions 17566
# 565
# number of particles 249
# number of collisions 16848
# 566
# number of particles 247
# number of collisions 16587
# 567
# number of particles 243
# number of collisions 16521
# 568
# number of particles 258
# number of collisions 18378
# 569
# number of particles 263
# number of collisions 19029
# 570
# number of particles 238
# number of collisions 16190
# 571
# number of particles 247
# number of collisions 17578
# 572
# number of particles 255
# number of collisions 18990
# 573
# number of particles 252
# number of collisions 18123
# 574
# number of particles 255
# number of collisions 18895
# 575
# number of particles 257
# number of collisions 20744
# 576
# number of particles 246
# number of collisions 17604
# 577
# number of particles 257
# number of collisions 18611
# 578
# number of particles 262
# number of collisions 19168
# 579
# number of particles 261
# number of collisions 21259
# 580
# number of particles 254
# number of collisions 18994
# 581
# number of particles 247
# number of collisions 16891
# 582
# number of particles 257
# number of collisions 20956
# 583
# number of particles 253
# number of collisions 19009
# 584
# number of particles 255
# number of collisions 17075
# 585
# number of particles 242
# number of collisions 16127
# 586
# number of particles 259
# number of collisions 21005
# 587
# number of particles 236
# number of collisions 14921
# 588
# number of particles 253
# number of collisions 19288
# 589
# number of particles 258
# number of collisions 17305
# 590
# number of particles 248
# number of collisions 15651
# 591
# number of particles 234
# number of collisions 14080
# 592
# number of particles 246
# number of collisions 17051
# 593
# number of particles 249
# number of collisions 16725
# 594
# number of particles 245
# number of collisions 16741
# 595
# number of particles 260
# number of collisions 19827
# 596
# number of particles 257
# number of collisions 20278
# 597
# number of particles 248
# number of collisions 17350
# 598
# number of particles 246
# number of collisions 16508
# 599
# number of particles 248
# number of collisions 16735
# 600
# number of particles 245
# number of collisions 17376
# 601
# number of particles 254
# number of collisions 18147
# 602
# number of particles 255
# number of collisions 18970
# 603
# number of particles 258
# number of collisions 18821
# 604
# number of particles 247
# number of collisions 17202
# 605
# number of particles 244
# number of collisions 15438
# 606
# number of particles 257
# number of collisions 20109
# 607
# number of particles 253
# number of collisions 18140
# 608
# number of particles 246
# number of collisions 16435
# 609
# number of particles 243
# number of collisions 15311
# 610
# number of particles 247
# number of collisions 15665
# 611
# number of particles 256
# number of collisions 20786
# 612
# number of particles 232
# number of collisions 13985
# 613
# number of particles 251
# number of collisions 16918
# 614
# number of particles 260
# number of collisions 20418
# 615
# number of particles 232
# number of collisions 12611
# 616
# number of particles 242
# number of collisions 16491
# 617
# number of particles 259
# number of collisions 19328
# 618
# number of particles 254
# number of collisions 18450
# 619
# number of particles 251
# number of collisions 18297
# 620
# number of particles 249
# number of collisions 17692
# 621
# number of particles 256
# number of collisions 18420
# 622
# number of particles 242
# number of collisions 16583
# 623
# number of particles 253
# number of collisions 18685
# 624
# number of particles 248
# number of collisions 17814
# 625
# number of particles 255
# number of collisions 20139
# 626
# number of particles 250
# number of collisions 18988
# 627
# number of particles 236
# number of collisions 15342
# 628
# number of particles 238
# number of collisions 15824
# 629
# number of particles 257
# number of collisions 18662
# 630
# number of particles 238
# number of collisions 16282
# 631
# number of particles 236
# number of collisions 14543
# 632
# number of particles 248
# number of collisions 17714
# 633
# number of particles 250
# number of collisions 18339
# 634
# number of particles 238
# number of collisions 15687
# 635
# number of particles 258
# number of collisions 19863
# 636
# number of particles 262
# number of collisions 20971
# 637
# number of particles 239
# number of collisions 14585
# 638
# number of particles 264
# number of collisions 21676
# 639
# number of particles 247
# number of collisions 17521
# 640
# number of particles 237
# number of collisions 13879
# 641
# number of particles 252
# number of collisions 18457
# 642
# number of particles 242
# number of collisions 15946
# 643
# number of particles 242
# number of collisions 15166
# 644
# number of particles 256
# number of collisions 19486
# 645
# number of particles 242
# number of collisions 17541
# 646
# number of particles 240
# number of collisions 16767
# 647
# number of particles 246
# number of collisions 16741
# 648
# number of particles 246
# number of collisions 17259
# 649
# number of particles 256
# number of collisions 18664
# 650
# number of particles 250
# number of collisions 17670
# 651
# number of particles 262
# number of collisions 20193
# 652
# number of particles 252
# number of collisions 17895
# 653
# number of particles 251
# number of collisions 18535
# 654
# number of particles 245
# number of collisions 16433
# 655
# number of particles 241
# number of collisions 15878
# 656
# number of particles 254
# number of collisions 16910
# 657
# number of particles 252
# number of collisions 17420
# 658
# number of particles 240
# number of collisions 17356
# 659
# number of particles 247
# number of collisions 16899
# 660
# number of particles 249
# number of collisions 17769
# 661
# number of particles 252
# number of collisions 17773
# 662
# number of particles 257
# number of collisions 20755
# 663
# number of particles 241
# number of collisions 16546
# 664
# number of particles 246
# number of collisions 16637
# 665
# number of particles 252
# number of collisions 18119
# 666
# number of particles 248
# number of collisions 16447
# 667
# number of particles 253
# number of collisions 18730
# 668
# number of particles 257
# number of collisions 18605
# 669
# number of particles 257
# number of collisions 19704
# 670
# number of particles 269
# number of collisions 22789
# 671
# number of particles 232
# number of collisions 14876
# 672
# number of particles 247
# number of collisions 17557
# 673
# number of particles 255
# number of collisions 18534
# 674
# number of particles 255
# number of collisions 19475
# 675
# number of particles 246
# number of collisions 16300
# 676
# number of particles 249
# number of collisions 16759
# 677
# number of particles 254
# number of collisions 17792
# 678
# number of particles 242
# number of collisions 15774
# 679
# number of particles 245
# number of collisions 15906
# 680
# number of particles 245
# number of collisions 17037
# 681
# number of particles 231
# number of collisions 13790
# 682
# number of particles 276
# number of collisions 23435
# 683
# number of particles 248
# number of collisions 17993
# 684
# number of particles 249
# number of collisions 17529
# 685
# number of particles 240
# number of collisions 14861
# 686
# number of particles 244
# number of collisions 17173
# 687
# number of particles 235
# number of collisions 15244
# 688
# number of particles 246
# number of collisions 15817
# 689
# number of particles 258
# number of collisions 18718
# 690
# number of particles 255
# number of collisions 18300
# 691
# number of particles 253
# number of collisions 18926
# 692
# number of particles 251
# number of collisions 18255
# 693
# number of particles 261
# number of collisions 20031
# 694
# number of particles 249
# number of collisions 17159
# 695
# number of particles 250
# number of collisions 18410
# 696
# number of particles 255
# number of collisions 17157
# 697
# number of particles 255
# number of collisions 17327
# 698
# number of particles 241
# number of collisions 15548
# 699
# number of particles 252
# number of collisions 17416
# 700
# number of particles 248
# number of collisions 17120
# 701
# number of particles 239
# number of collisions 15461
# 702
# number of particles 241
# number of collisions 16206
# 703
# number of particles 247
# number of collisions 17001
# 704
# number of particles 251
# number of collisions 17561
# 705
# number of particles 234
# number of collisions 15178
# 706
# number of particles 247
# number of collisions 16895
# 707
# number of particles 255
# number of collisions 19237
# 708
# number of particles 257
# number of collisions 20085
# 709
# number of particles 244
# number of collisions 17089
# 710
# number of particles 254
# number of collisions 17418
# 711
# number of particles 256
# number of collisions 19019
# 712
# number of particles 240
# number of collisions 14695
# 713
# number of particles 247
# number of collisions 17460
# 714
# number of particles 247
# number of collisions 16943
# 715
# number of particles 256
# number of collisions 18668
# 716
# number of particles 263
# number of collisions 20429
# 717
# number of particles 245
# number of collisions 16552
# 718
# number of particles 259
# number of collisions 19827
# 719
# number of particles 240
# number of collisions 14808
# 720
# number of particles 242
# number of collisions 15476
# 721
# number of particles 230
# number of collisions 13795
# 722
# number of particles 246
# number of collisions 17545
# 723
# number of particles 233
# number of collisions 14769
# 724
# number of particles 238
# number of collisions 15211
# 725
# number of particles 251
# number of collisions 17206
# 726
# number of particles 255
# number of collisions 18925
# 727
# number of particles 252
# number of collisions 17753
# 728
# number of particles 259
# number of collisions 20796
# 729
# number of particles 256
# number of collisions 18432
# 730
# number of particles 239
# number of collisions 15207
# 731
# number of particles 236
# number of collisions 14901
# 732
# number of particles 238
# number of collisions 15378
# 733
# number of particles 247
# number of collisions 16485
# 734
# number of particles 243
# number of collisions 15675
# 735
# number of particles 251
# number of collisions 17935
# 736
# number of particles 245
# number of collisions 16282
# 737
# number of particles 248
# number of collisions 16033
# 738
# number of particles 249
# number of collisions 17787
# 739
# number of particles 246
# number of collisions 16678
# 740
# number of particles 242
# number of collisions 16719
# 741
# number of particles 243
# number of collisions 15972
# 742
# number of particles 258
# number of collisions 18656
# 743
# number of particles 259
# number of collisions 18941
# 744
# number of particles 255
# number of collisions 18037
# 745
# number of particles 253
# number of collisions 17607
# 746
# number of particles 246
# number of collisions 16419
# 747
# number of particles 246
# number of collisions 16028
# 748
# number of particles 253
# number of collisions 19297
# 749
# number of particles 256
# number of collisions 18570
# 750
# number of particles 253
# number of collisions 20809
# 751
# number of particles 260
# number of collisions 19467
# 752
# number of particles 248
# number of collisions 17863
# 753
# number of particles 226
# number of collisions 13843
# 754
# number of particles 252
# number of collisions 18155
# 755
# number of particles 228
# number of collisions 12660
# 756
# number of particles 241
# number of collisions 16102
# 757
# number of particles 256
# number of collisions 20666
# 758
# number of particles 245
# number of collisions 16448
# 759
# number of particles 245
# number of collisions 16624
# 760
# number of particles 260
# number of collisions 20329
# 761
# number of particles 260
# number of collisions 21592
# 762
# number of particles 246
# number of collisions 16483
# 763
# number of particles 245
# number of collisions 18090
# 764
# number of particles 254
# number of collisions 18698
# 765
# number of particles 236
# number of collisions 14252
# 766
# number of particles 245
# number of collisions 17101
# 767
# number of particles 252
# number of collisions 19565
# 768
# number of particles 246
# number of collisions 16846
# 769
# number of particles 243
# number of collisions 16441
# 770
# number of particles 253
# number of collisions 18605
# 771
# number of particles 235
# number of collisions 14667
# 772
# number of particles 268
# number of collisions 23041
# 773
# number of particles 256
# number of collisions 20224
# 774
# number of particles 242
# number of collisions 16193
# 775
# number of particles 250
# number of collisions 17604
# 776
# number of particles 259
# number of collisions 19585
# 777
# number of particles 248
# number of collisions 17032
# 778
# number of particles 232
# number of collisions 13243
# 779
# number of particles 255
# number of collisions 19153
# 780
# number of particles 260
# number of collisions 18267
# 781
# number of particles 252
# number of collisions 17287
# 782
# number of particles 254
# number of collisions 17204
# 783
# number of particles 247
# number of collisions 17205
# 784
# number of particles 246
# number of collisions 16004
# 785
# number of particles 251
# number of collisions 17426
# 786
# number of particles 250
# number of collisions 18201
# 787
# number of particles 252
# number of collisions 17146
# 788
# number of particles 248
# number of collisions 16598
# 789
# number of particles 248
# number of collisions 17082
# 790
# number of particles 259
# number of collisions 20413
# 791
# number of particles 237
# number of collisions 13924
# 792
# number of particles 240
# number of collisions 15311
# 793
# number of particles 252
# number of collisions 18202
# 794
# number of particles 255
# number of collisions 19409
# 795
# number of particles 243
# number of collisions 16757
# 796
# number of particles 251
# number of collisions 15856
# 797
# number of particles 245
# number of collisions 16926
# 798
# number of particles 244
# number of collisions 15740
# 799
# number of particles 257
# number of collisions 20130
# 800
# number of particles 258
# number of collisions 20678
# 801
# number of particles 259
# number of collisions 20304
# 802
# number of particles 251
# number of collisions 17751
# 803
# number of particles 251
# number of collisions 17273
# 804
# number of particles 246
# number of collisions 17046
# 805
# number of particles 245
# number of collisions 16648
# 806
# number of particles 244
# number of collisions 17363
# 807
# number of particles 253
# number of collisions 18811
# 808
# number of particles 235
# number of collisions 14920
# 809
# number of particles 256
# number of collisions 17889
# 810
# number of particles 246
# number of collisions 14845
# 811
# number of particles 248
# number of collisions 17357
# 812
# number of particles 235
# number of collisions 14051
# 813
# number of particles 252
# number of collisions 18032
# 814
# number of particles 258
# number of collisions 18933
# 815
# number of particles 243
# number of collisions 16896
# 816
# number of particles 257
# number of collisions 18690
# 817
# number of particles 258
# number of collisions 20310
# 818
# number of particles 240
# number of collisions 15374
# 819
# number of particles 250
# number of collisions 17037
# 820
# number of particles 247
# number of collisions 16193
# 821
# number of particles 239
# number of collisions 16093
# 822
# number of particles 252
# number of collisions 17725
# 823
# number of particles 235
# number of collisions 15000
# 824
# number of particles 246
# number of collisions 16304
# 825
# number of particles 258
# number of collisions 18751
# 826
# number of particles 250
# number of collisions 17971
# 827
# number of particles 244
# number of collisions 17382
# 828
# number of particles 235
# number of collisions 14033
# 829
# number of particles 257
# number of collisions 20091
# 830
# number of particles 245
# number of collisions 17035
# 831
# number of particles 262
# number of collisions 18947
# 832
# number of particles 258
# number of collisions 18544
# 833
# number of particles 256
# number of collisions 18935
# 834
# number of particles 243
# number of collisions 15343
# 835
# number of particles 242
# number of collisions 15746
# 836
# number of particles 256
# number of collisions 19640
# 837
# number of particles 236
# number of collisions 14467
# 838
# number of particles 243
# number of collisions 16597
# 839
# number of particles 239
# number of collisions 15959
# 840
# number of particles 239
# number of collisions 15760
# 841
# number of particles 253
# number of collisions 17898
# 842
# number of particles 244
# number of collisions 17619
# 843
# number of particles 247
# number of collisions 17502
# 844
# number of particles 245
# number of collisions 16691
# 845
# number of particles 245
# number of collisions 14873
# 846
# number of particles 261
# number of collisions 19594
# 847
# number of particles 253
# number of collisions 17453
# 848
# number of particles 255
# number of collisions 18320
# 849
# number of particles 250
# number of collisions 17857
# 850
# number of particles 235
# number of collisions 15244
# 851
# number of particles 238
# number of collisions 14390
# 852
# number of particles 264
# number of collisions 21177
# 853
# number of particles 252
# number of collisions 18557
# 854
# number of particles 250
# number of collisions 18295
# 855
# number of particles 252
# number of collisions 18133
# 856
# number of particles 241
# number of collisions 16982
# 857
# number of particles 237
# number of collisions 14067
# 858
# number of particles 260
# number of collisions 19034
# 859
# number of particles 246
# number of collisions 17078
# 860
# number of particles 251
# number of collisions 17645
# 861
# number of particles 249
# number of collisions 18001
# 862
# number of particles 261
# number of collisions 20203
# 863
# number of particles 252
# number of collisions 16363
# 864
# number of particles 266
# number of collisions 21434
# 865
# number of particles 237
# number of collisions 16015
# 866
# number of particles 260
# number of collisions 20312
# 867
# number of particles 240
# number of collisions 15676
# 868
# number of particles 250
# number of collisions 17057
# 869
# number of particles 246
# number of collisions 17140
# 870
# number of particles 240
# number of collisions 14110
# 871
# number of particles 255
# number of collisions 17419
# 872
# number of particles 248
# number of collisions 17673
# 873
# number of particles 255
# number of collisions 19458
# 874
# number of particles 253
# number of collisions 17835
# 875
# number of particles 254
# number of collisions 18085
# 876
# number of particles 240
# number of collisions 15531
# 877
# number of particles 250
# number of collisions 17512
# 878
# number of particles 243
# number of collisions 17176
# 879
# number of particles 242
# number of collisions 15993
# 880
# number of particles 245
# number of collisions 17546
# 881
# number of particles 250
# number of collisions 17939
# 882
# number of particles 250
# number of collisions 16799
# 883
# number of particles 258
# number of collisions 19663
# 884
# number of particles 240
# number of collisions 15468
# 885
# number of particles 250
# number of collisions 18247
# 886
# number of particles 250
# number of collisions 17426
# 887
# number of particles 256
# number of collisions 20101
# 888
# number of particles 247
# number of collisions 17076
# 889
# number of particles 241
# number of collisions 14841
# 890
# number of particles 237
# number of collisions 13881
# 891
# number of particles 240
# number of collisions 15916
# 892
# number of particles 265
# number of collisions 20534
# 893
# number of particles 254
# number of collisions 19548
# 894
# number of particles 252
# number of collisions 16818
# 895
# number of particles 251
# number of collisions 18483
# 896
# number of particles 237
# number of collisions 14551
# 897
# number of particles 247
# number of collisions 15702
# 898
# number of particles 247
# number of collisions 16987
# 899
# number of particles 222
# number of collisions 12369
# 900
# number of particles 254
# number of collisions 18001
# 901
# number of particles 254
# number of collisions 17852
# 902
# number of particles 254
# number of collisions 19133
# 903
# number of particles 243
# number of collisions 16456
# 904
# number of particles 244
# number of collisions 16628
# 905
# number of particles 253
# number of collisions 15878
# 906
# number of particles 245
# number of collisions 15885
# 907
# number of particles 246
# number of collisions 17411
# 908
# number of particles 239
# number of collisions 15060
# 909
# number of particles 248
# number of collisions 15348
# 910
# number of particles 242
# number of collisions 15587
# 911
# number of particles 248
# number of collisions 17321
# 912
# number of particles 241
# number of collisions 17903
# 913
# number of particles 250
# number of collisions 17806
# 914
# number of particles 264
# number of collisions 21098
# 915
# number of particles 236
# number of collisions 14559
# 916
# number of particles 254
# number of collisions 18719
# 917
# number of particles 236
# number of collisions 15005
# 918
# number of particles 255
# number of collisions 18778
# 919
# number of particles 256
# number of collisions 19094
# 920
# number of particles 254
# number of collisions 17385
# 921
# number of particles 242
# number of collisions 16567
# 922
# number of particles 252
# number of collisions 19003
# 923
# number of particles 252
# number of collisions 18708
# 924
# number of particles 253
# number of collisions 18762
# 925
# number of particles 233
# number of collisions 14818
# 926
# number of particles 249
# number of collisions 17006
# 927
# number of particles 263
# number of collisions 20024
# 928
# number of particles 247
# number of collisions 15622
# 929
# number of particles 242
# number of collisions 16698
# 930
# number of particles 265
# number of collisions 19483
# 931
# number of particles 249
# number of collisions 18527
# 932
# number of particles 242
# number of collisions 16896
# 933
# number of particles 253
# number of collisions 18091
# 934
# number of particles 242
# number of collisions 15947
# 935
# number of particles 238
# number of collisions 15595
# 936
# number of particles 259
# number of collisions 19352
# 937
# number of particles 236
# number of collisions 14741
# 938
# number of particles 240
# number of collisions 15866
# 939
# number of particles 248
# number of collisions 18595
# 940
# number of particles 248
# number of collisions 17509
# 941
# number of particles 244
# number of collisions 16872
# 942
# number of particles 260
# number of collisions 20801
# 943
# number of particles 255
# number of collisions 18441
# 944
# number of particles 260
# number of collisions 19762
# 945
# number of particles 260
# number of collisions 19039
# 946
# number of particles 251
# number of collisions 18954
# 947
# number of particles 258
# number of collisions 20388
# 948
# number of particles 257
# number of collisions 18591
# 949
# number of particles 244
# number of collisions 16122
# 950
# number of particles 259
# number of collisions 18234
# 951
# number of particles 249
# number of collisions 17321
# 952
# number of particles 253
# number of collisions 18159
# 953
# number of particles 255
# number of collisions 18764
# 954
# number of particles 244
# number of collisions 14936
# 955
# number of particles 250
# number of collisions 17916
# 956
# number of particles 241
# number of collisions 16541
# 957
# number of particles 260
# number of collisions 20203
# 958
# number of particles 252
# number of collisions 18180
# 959
# number of particles 255
# number of collisions 17575
# 960
# number of particles 251
# number of collisions 17776
# 961
# number of particles 240
# number of collisions 15180
# 962
# number of particles 230
# number of collisions 14193
# 963
# number of particles 247
# number of collisions 17224
# 964
# number of particles 253
# number of collisions 17783
# 965
# number of particles 246
# number of collisions 15435
# 966
# number of particles 258
# number of collisions 19560
# 967
# number of particles 248
# number of collisions 16590
# 968
# number of particles 251
# number of collisions 18532
# 969
# number of particles 234
# number of collisions 15900
# 970
# number of particles 244
# number of collisions 16230
# 971
# number of particles 248
# number of collisions 16139
# 972
# number of particles 242
# number of collisions 15811
# 973
# number of particles 248
# number of collisions 15934
# 974
# number of particles 248
# number of collisions 15973
# 975
# number of particles 239
# number of collisions 16833
# 976
# number of particles 265
# number of collisions 21061
# 977
# number of particles 257
# number of collisions 18951
# 978
# number of particles 254
# number of collisions 17932
# 979
# number of particles 241
# number of collisions 16406
# 980
# number of particles 251
# number of collisions 16659
# 981
# number of particles 246
# number of collisions 16182
# 982
# number of particles 253
# number of collisions 18105
# 983
# number of particles 249
# number of collisions 17149
# 984
# number of particles 253
# number of collisions 17956
# 985
# number of particles 258
# number of collisions 18554
# 986
# number of particles 266
# number of collisions 20947
# 987
# number of particles 247
# number of collisions 16487
# 988
# number of particles 244
# number of collisions 15307
# 989
# number of particles 244
# number of collisions 16850
# 990
# number of particles 232
# number of collisions 14758
# 991
# number of particles 258
# number of collisions 17882
# 992
# number of particles 242
# number of collisions 15660
# 993
# number of particles 245
# number of collisions 16995
# 994
# number of particles 269
# number of collisions 19618
# 995
# number of particles 241
# number of collisions 16716
# 996
# number of particles 250
# number of collisions 18474
# 997
# number of particles 252
# number of collisions 19707
# 998
# number of particles 249
# number of collisions 15225
# 999
# <ipython-input-1-e404909ccac2>:254: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm1 = plt.pcolormesh(X, T, C0.T)
# <ipython-input-1-e404909ccac2>:261: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm2 = plt.pcolormesh(X, T, C1.T)
# <ipython-input-1-e404909ccac2>:268: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm3 = plt.pcolormesh(X, T, C2.T)
# <ipython-input-1-e404909ccac2>:275: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm4 = plt.pcolormesh(X, T, C3.T)
# <ipython-input-1-e404909ccac2>:282: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm5 = plt.pcolormesh(X, T, C4.T)
# <ipython-input-1-e404909ccac2>:289: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm6 = plt.pcolormesh(X, T, C5.T)
# <ipython-input-1-e404909ccac2>:300: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm7 = plt.pcolormesh(X, T,np.abs(C0IFT1).T, vmin = 0, vmax = 20)
# <ipython-input-1-e404909ccac2>:309: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm8 = plt.pcolormesh(X, T,np.abs(C0IFT2).T, vmin = 0, vmax = 20)
# <ipython-input-1-e404909ccac2>:318: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm9 = plt.pcolormesh(X, T,np.abs(C1IFT1).T, vmin = 0, vmax = 20)
# <ipython-input-1-e404909ccac2>:327: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm10 = plt.pcolormesh(X, T,np.abs(C1IFT2).T, vmin = 0, vmax = 20)
# <ipython-input-1-e404909ccac2>:336: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm11 = plt.pcolormesh(X, T,np.abs(C2IFT1).T, vmin = 0, vmax = 20)
# <ipython-input-1-e404909ccac2>:345: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm12 = plt.pcolormesh(X, T,np.abs(C2IFT2).T, vmin = 0, vmax = 20)
# <ipython-input-1-e404909ccac2>:354: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm13 = plt.pcolormesh(X, T,np.abs(C3IFT1).T, vmin = 0, vmax = 20)
# <ipython-input-1-e404909ccac2>:363: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm14 = plt.pcolormesh(X, T,np.abs(C3IFT2).T, vmin = 0, vmax = 20)
# <ipython-input-1-e404909ccac2>:372: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm15 = plt.pcolormesh(X, T,np.abs(C4IFT1).T, vmin = 0, vmax = 20)
# <ipython-input-1-e404909ccac2>:381: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm16 = plt.pcolormesh(X, T,np.abs(C4IFT2).T, vmin = 0, vmax = 20)
# <ipython-input-1-e404909ccac2>:390: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm17 = plt.pcolormesh(X, T,np.abs(C5IFT1).T, vmin = 0, vmax = 20)
# <ipython-input-1-e404909ccac2>:399: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pcm18 = plt.pcolormesh(X, T,np.abs(C5IFT2).T, vmin = 0, vmax = 20)
